# %% [markdown]
# # Assignment 1: Print Statements and Input

# %% [markdown]
# #### Task 1: Print a greeting message.

# %%
print("Hello, welcome to your Python journey!")
# Out:
# Hello, welcome to your Python journey!

# %% [markdown]
# #### Task 2: Print your name using a print statement.

# %%
print("My name is Ayleen Haider")
# Out:
# My name is Ayleen Haider

# %% [markdown]
# #### Task 3: Take user input for their name and print a greeting.

# %%
name=input("Enter your name: ")
print("Hello ",name)
# Out:
# Enter your name: Ayleen
# Hello  Ayleen

# %% [markdown]
# #### Task 4: Take two fixed numbers and print their sum.

# %%
num1=10
num2=3
sum=num1+num2
print("The sum is: "sum)

# %% [markdown]
# ###  Sample Outputs
#
#
# ```
# Hello, welcome to your Python journey!
# My name is Huzaifa Siddiqui
# Hello John Doe, welcome to Python!
# The sum is: 13
# ```

# %%
print("Hello, welcome to your Python journey!")
print("My name is Ayleen Haider")
name=input("Enter your name: ")
print("Hello ",name)
num1=10
num2=3
sum=num1+num2
print("The sum is: ",sum)
# Out:
# Hello, welcome to your Python journey!
# My name is Ayleen Haider
# Enter your name: Ayleen
# Hello  Ayleen
# The sum is:  13
