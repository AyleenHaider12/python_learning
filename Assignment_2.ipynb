# %% [markdown]
# # Assignment 2: Data Types, Numbers, Operations, Type Conversions, f-Strings

# %% [markdown]
# #### Task 1: Convert a string to integer and perform arithmetic.

# %%
num_str="7"
num_int=int(num_str)
square= num_int**2
print("The square of", num_int,"is",square)
# Out:
# The square of 7 is 49

# %% [markdown]
# #### Task 2: Show examples of different data types: int, float, string, boolean.

# %%
a=0.1
print(type(a))
b=3
print(type(b))
c="Ayleen"
print(type(c))
d=35>20
print(type(d))
# Out:
# <class 'float'>
# <class 'int'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# #### Task 3: Perform basic arithmetic operations.

# %%
num1=10
num2=3
sum=num1+num2
print("Addition: ",sum)
sub=num1-num2
print("Subtraction: ",sub)
multi=num1*num2
print("Multiplication: ",multi)
divide=num1/num2
print("Divivsion: ",divide)
# Out:
# Addition:  13
# Subtraction:  7
# Multiplication:  30
# Divivsion:  3.3333333333333335

# %% [markdown]
# #### Task 4: Convert Celsius to Fahrenheit with fixed Celsius input.

# %%
celsius=37
conv=(celsius*9/5) + 32
print(celsius,"C is equal to ",conv)
# Out:
# 37 C is equal to  98.6

# %% [markdown]
# ### Sample Outputs
#
#
# ```
# The square of 7 is 49
# Data types: <class 'int'>, <class 'float'>, <class 'str'>, <class 'bool'>
# Addition: 13, Subtraction: 7, Multiplication: 30, Division: 3.3333333333333335
# 37°C is equal to 98.6°F
# ```
